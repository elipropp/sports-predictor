# %%
import pandas as pd

# %%
df1 = pd.read_pickle('data_df_2015-2020-first-26-endpoints-4-cols.pickle')
df2 = pd.read_pickle('data_df_2015-2020-second-24-endpoints-4-cols.pickle')

# %%
df1.iloc[500:600]
# Out:
#                          effective-field-goal-pct-SeasonSoFar  \
# 2014-11-24 Okla City                                     45.9
#            Orlando                                       50.5
#            Philadelphia                                  45.2
#            Phoenix                                       50.8
#            Portland                                      51.7
# ...                                                       ...
# 2014-11-27 Sacramento                                    48.2
#            San Antonio                                   50.6
#            Toronto                                       50.6
#            Utah                                          50.6
#            Washington                                    49.6
#
#                          effective-field-goal-pct-Last3  \
# 2014-11-24 Okla City                               45.1
#            Orlando                                 47.0
# ...

# %%
df2.iloc[500:600]
# Out:
#                          offensive-efficiency-SeasonSoFar  \
# 2014-11-24 Okla City                                0.947
#            Orlando                                  0.999
#            Philadelphia                             0.880
#            Phoenix                                  1.044
#            Portland                                 1.071
# ...                                                   ...
# 2014-11-27 Sacramento                               1.041
#            San Antonio                              1.011
#            Toronto                                  1.108
#            Utah                                     1.020
#            Washington                               1.010
#
#                          offensive-efficiency-Last3  \
# 2014-11-24 Okla City                          0.984
#            Orlando                            1.014
#            Philadelphia                       0.913
#            Phoenix                            1.094
# ...

# %%
joined_df = pd.concat([df1, df2], axis=1)

# %%
joined_df
# Out:
#                         effective-field-goal-pct-SeasonSoFar  \
# 2014-11-08 Atlanta                                      52.8
#            Boston                                       50.9
#            Brooklyn                                     54.7
#            Charlotte                                    47.1
#            Chicago                                      53.8
# ...                                                      ...
# 2019-03-31 Sacramento                                   52.4
#            San Antonio                                  53.4
#            Toronto                                      54.2
#            Utah                                         53.5
#            Washington                                   53.4
#
#                         effective-field-goal-pct-Last3  \
# 2014-11-08 Atlanta                                51.2
#            Boston                                 52.5
#            Brooklyn                               56.0
# ...

# %%
joined_df.to_pickle('data_df_2015-2020-200-DataPoints.pickle')

# %%
joined_df.to_csv('data_df_2015-2020-200-DataPoints.csv')
